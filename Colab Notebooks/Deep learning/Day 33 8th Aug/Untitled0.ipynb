# %%
import os

# %%
ROOT = "/content/drive/MyDrive/001_SUNNY_BHAVEEN_CHANDRA/001_My_Classes/DLCVNLP/Live Lectures Material DLCVNLP April 17th batch/ALL NOTES/Day 33 8th Aug"

os.chdir(ROOT)

# %%
from zipfile import ZipFile

# %%
with ZipFile("opencv.zip") as f:
  f.extractall()
