# %%
zip_file_url = "https://files.consumerfinance.gov/ccdb/complaints.csv.zip"

# %%
import requests, zipfile, io
r = requests.get(zip_file_url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall("/content/sample_data")

# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/complaints.csv")
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (9,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.shape
# Out:
# (3278773, 18)

# %%
df.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
df.head()
# Out:
#   Date received                                            Product  \
# 0    2023-01-29  Credit reporting, credit repair services, or o...
# 1    2023-01-29  Credit reporting, credit repair services, or o...
# 2    2023-01-29  Credit reporting, credit repair services, or o...
# 3    2023-01-29  Credit reporting, credit repair services, or o...
# 4    2023-01-29  Credit reporting, credit repair services, or o...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting                        Improper use of your report
# 1  Credit reporting  Problem with a credit reporting company's inve...
# 2  Credit reporting  Problem with a credit reporting company's inve...
# 3  Credit reporting  Problem with a credit reporting company's inve...
# 4  Credit reporting  Problem with a credit reporting company's inve...
#
#                                            Sub-issue  \
# 0      Reporting company used your report improperly
# 1  Their investigation did not fix an error on yo...
# 2  Their investigation did not fix an error on yo...
# 3  Their investigation did not fix an error on yo...
# 4  Their investigation did not fix an error on yo...
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
#                                   Company State ZIP code Tags  \
# 0  TRANSUNION INTERMEDIATE HOLDINGS, INC.    AZ  85713.0  NaN
# 1  TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX  77082.0  NaN
# 2  TRANSUNION INTERMEDIATE HOLDINGS, INC.    FL  33020.0  NaN
# 3  TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX  77082.0  NaN
# 4  TRANSUNION INTERMEDIATE HOLDINGS, INC.    TX  77082.0  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN           Web           2023-01-29
# 1                        NaN           Web           2023-01-29
# 2                        NaN           Web           2023-01-29
# 3                        NaN           Web           2023-01-29
# 4                        NaN           Web           2023-01-29
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0                  In progress              Yes                NaN
# 1                  In progress              Yes                NaN
# 2                  In progress              Yes                NaN
# 3                  In progress              Yes                NaN
# 4                  In progress              Yes                NaN
#
#    Complaint ID
# 0       6498577
# 1       6498594
# 2       6498474
# 3       6498476
# 4       6498505

# %%
df.tail()
# Out:
#         Date received           Product                  Sub-product  \
# 3278768    2017-02-09   Debt collection                I do not know
# 3278769    2015-04-29          Mortgage  Conventional fixed mortgage
# 3278770    2017-03-31  Credit reporting                          NaN
# 3278771    2017-01-16  Credit reporting                          NaN
# 3278772    2018-03-07          Mortgage       Other type of mortgage
#
#                                             Issue  \
# 3278768     Cont'd attempts collect debt not owed
# 3278769  Loan modification,collection,foreclosure
# 3278770  Credit reporting company's investigation
# 3278771    Incorrect information on credit report
# 3278772            Trouble during payment process
#
#                                         Sub-issue  \
# 3278768         Debt resulted from identity theft
# 3278769                                       NaN
# 3278770  No notice of investigation status/result
# 3278771                            Account status
# 3278772                                       NaN
#
#                               Consumer complaint narrative  \
# 3278768  I have disputed my debts several times with no...
# 3278769  My father died in XX/XX/XXXX. Left me his only...
# 3278770  cfbp i would Like to file a complaint on Exper...
# 3278771  My husband and I are in the middle of an FHA S...
# 3278772                                                NaN
#
#                                    Company public response  \
# 3278768                                                NaN
# 3278769                                                NaN
# 3278770  Company has responded to the consumer and the ...
# 3278771  Company has responded to the consumer and the ...
# 3278772  Company has responded to the consumer and the ...
#
#                                         Company State ZIP code           Tags  \
# 3278768      Bonneville Billing and Collections    UT  84054.0  Servicemember
# 3278769                          CITIBANK, N.A.    OK  74066.0            NaN
# 3278770     Experian Information Solutions Inc.    MN  55379.0            NaN
# 3278771  TRANSUNION INTERMEDIATE HOLDINGS, INC.    GA  30215.0            NaN
# 3278772                   WELLS FARGO & COMPANY    CA  91304.0            NaN
#
#         Consumer consent provided? Submitted via Date sent to company  \
# 3278768           Consent provided           Web           2017-02-09
# 3278769           Consent provided           Web           2015-04-29
# 3278770           Consent provided           Web           2017-03-31
# 3278771           Consent provided           Web           2017-01-16
# 3278772                        NaN      Referral           2018-03-08
#
#             Company response to consumer Timely response? Consumer disputed?  \
# 3278768          Closed with explanation              Yes                 No
# 3278769          Closed with explanation              Yes                 No
# 3278770  Closed with non-monetary relief              Yes                Yes
# 3278771          Closed with explanation              Yes                 No
# 3278772          Closed with explanation              Yes                NaN
#
#          Complaint ID
# 3278768       2334969
# 3278769       1352738
# 3278770       2412926
# 3278771       2292586
# 3278772       2837068

# %%
df["Tags"].unique()
# Out:
# array([nan, 'Servicemember', 'Older American, Servicemember',
#        'Older American'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Date received                         0
# Product                               0
# Sub-product                      235293
# Issue                                 0
# Sub-issue                        691412
# Consumer complaint narrative    2094935
# Company public response         1830896
# Company                               0
# State                             40534
# ZIP code                          41017
# Tags                            2912373
# Consumer consent provided?       837314
# Submitted via                         0
# Date sent to company                  0
# Company response to consumer          4
# Timely response?                      0
# Consumer disputed?              2510346
# Complaint ID                          0
# dtype: int64

# %%
df.isna().mean()
# Out:
# Date received                   0.000000
# Product                         0.000000
# Sub-product                     0.071763
# Issue                           0.000000
# Sub-issue                       0.210875
# Consumer complaint narrative    0.638939
# Company public response         0.558409
# Company                         0.000000
# State                           0.012363
# ZIP code                        0.012510
# Tags                            0.888251
# Consumer consent provided?      0.255374
# Submitted via                   0.000000
# Date sent to company            0.000000
# Company response to consumer    0.000001
# Timely response?                0.000000
# Consumer disputed?              0.765636
# Complaint ID                    0.000000
# dtype: float64

# %%
df.nunique()
# Out:
# Date received                      4076
# Product                              18
# Sub-product                          76
# Issue                               165
# Sub-issue                           221
# Consumer complaint narrative    1029148
# Company public response              11
# Company                            6625
# State                                63
# ZIP code                          60697
# Tags                                  3
# Consumer consent provided?            4
# Submitted via                         7
# Date sent to company               4025
# Company response to consumer          8
# Timely response?                      2
# Consumer disputed?                    2
# Complaint ID                    3278773
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3278773 entries, 0 to 3278772
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 object
#  1   Product                       object
#  2   Sub-product                   object
#  3   Issue                         object
#  4   Sub-issue                     object
#  5   Consumer complaint narrative  object
#  6   Company public response       object
#  7   Company                       object
#  8   State                         object
#  9   ZIP code                      object
#  10  Tags                          object
#  11  Consumer consent provided?    object
#  12  Submitted via                 object
#  13  Date sent to company          object
#  14  Company response to consumer  object
#  15  Timely response?              object
#  16  Consumer disputed?            object
#  17  Complaint ID                  int64
# dtypes: int64(1), object(17)
# memory usage: 450.3+ MB

# %%
ls -lh
# Out:
# total 8.0K
# drwx------ 6 root root 4.0K Jan 30 15:52 drive/
# drwxr-xr-x 1 root root 4.0K Jan 30 15:53 sample_data/

# %%
# a = df1.value_counts()[0]
# b = df1.value_counts()[1]
# a,b

# %%
df1 = df.dropna()

# %%
df1.shape
# Out:
# (3120, 18)

# %%
df2 = df[df["Consumer disputed?"].notna()].reset_index(drop=True)

# %%
df2.head()
# Out:
#   Date received           Product                             Sub-product  \
# 0    2016-11-09   Debt collection                                 Medical
# 1    2013-11-04  Credit reporting                                     NaN
# 2    2012-07-02       Credit card                                     NaN
# 3    2012-11-16          Mortgage  Conventional adjustable mortgage (ARM)
# 4    2017-04-20   Debt collection   Other (i.e. phone, health club, etc.)
#
#                                       Issue  \
# 0     Cont'd attempts collect debt not owed
# 1    Incorrect information on credit report
# 2                            Payoff process
# 3  Loan modification,collection,foreclosure
# 4           Disclosure verification of debt
#
#                               Sub-issue Consumer complaint narrative  \
# 0                      Debt is not mine                          NaN
# 1                        Account status                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4  Not given enough info to verify debt                          NaN
#
#                              Company public response  \
# 0  Company believes complaint caused principally ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Company believes the complaint is the result o...
#
#                                       Company State ZIP code  \
# 0  Firstsource Business Process Services, LLC    WI  54703.0
# 1      TRANSUNION INTERMEDIATE HOLDINGS, INC.    MO  63042.0
# 2                               DISCOVER BANK    NC  27513.0
# 3                       WELLS FARGO & COMPANY    CA  92121.0
# 4                             HW Holding, Inc    GA  30318.0
#
#                             Tags Consumer consent provided? Submitted via  \
# 0                            NaN       Consent not provided           Web
# 1  Older American, Servicemember                        NaN   Postal mail
# 2                            NaN                        NaN           Web
# 3                            NaN                        NaN           Web
# 4                            NaN                        NaN   Postal mail
#
#   Date sent to company     Company response to consumer Timely response?  \
# 0           2016-11-27          Closed with explanation              Yes
# 1           2013-11-13          Closed with explanation              Yes
# 2           2012-07-03      Closed with monetary relief              Yes
# 3           2012-11-19  Closed with non-monetary relief              Yes
# 4           2017-04-21          Closed with explanation              Yes
#
#   Consumer disputed?  Complaint ID
# 0                 No       2202626
# 1                 No        583787
# 2                 No        111425
# 3                 No        193409
# 4                 No       2445864

# %%
df2.shape
# Out:
# (768427, 18)

# %%
df2.isna().mean()
# Out:
# Date received                   0.000000
# Product                         0.000000
# Sub-product                     0.306030
# Issue                           0.000000
# Sub-issue                       0.592639
# Consumer complaint narrative    0.786507
# Company public response         0.745312
# Company                         0.000000
# State                           0.007353
# ZIP code                        0.007349
# Tags                            0.858808
# Consumer consent provided?      0.612352
# Submitted via                   0.000000
# Date sent to company            0.000000
# Company response to consumer    0.000000
# Timely response?                0.000000
# Consumer disputed?              0.000000
# Complaint ID                    0.000000
# dtype: float64

# %%
# Using this location as a root Directory
import os
ROOT = "/content/drive/MyDrive/Colab Notebooks/Deep learning"
os.chdir(ROOT)

# %%
ls
# Out:
# 'activation function.ipynb'                logs/
#  ANN_with_callbacks.ipynb                  Mnest.ipynb
#  APS_in_dl.ipynb                           model_ckp.h5
# 'Batch Normalization.ipynb'                model.h5
# 'CNN basics .ipynb'                        project1/
#  Dataset/                                  project3/
# 'Handwritten Digit Classification.ipynb'   SAVED_MODELS/

# %%
# mkdir "Dataset"

# %%
ls
# Out:
# 'activation function.ipynb'                logs/
#  ANN_with_callbacks.ipynb                  Mnest.ipynb
#  APS_in_dl.ipynb                           model_ckp.h5
# 'Batch Normalization.ipynb'                model.h5
# 'CNN basics .ipynb'                        project1/
#  Dataset/                                  project3/
# 'Handwritten Digit Classification.ipynb'   SAVED_MODELS/

# %%
cd "Dataset"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Deep learning/Dataset

# %%
ls

# %%
# df2.to_csv("Sample.csv",index=False)

# %%
# import pandas as pd 
# df = pd.read_csv("Sample.csv")
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (5,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head(5)
# Out:
#   Date received           Product                             Sub-product  \
# 0    2016-11-09   Debt collection                                 Medical
# 1    2013-11-04  Credit reporting                                     NaN
# 2    2012-07-02       Credit card                                     NaN
# 3    2012-11-16          Mortgage  Conventional adjustable mortgage (ARM)
# 4    2017-04-20   Debt collection   Other (i.e. phone, health club, etc.)
#
#                                       Issue  \
# 0     Cont'd attempts collect debt not owed
# 1    Incorrect information on credit report
# 2                            Payoff process
# 3  Loan modification,collection,foreclosure
# 4           Disclosure verification of debt
#
#                               Sub-issue Consumer complaint narrative  \
# 0                      Debt is not mine                          NaN
# 1                        Account status                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4  Not given enough info to verify debt                          NaN
#
#                              Company public response  \
# 0  Company believes complaint caused principally ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Company believes the complaint is the result o...
#
#                                       Company State ZIP code  \
# 0  Firstsource Business Process Services, LLC    WI  54703.0
# 1      TRANSUNION INTERMEDIATE HOLDINGS, INC.    MO  63042.0
# 2                               DISCOVER BANK    NC  27513.0
# 3                       WELLS FARGO & COMPANY    CA  92121.0
# 4                             HW Holding, Inc    GA  30318.0
#
#                             Tags Consumer consent provided? Submitted via  \
# 0                            NaN       Consent not provided           Web
# 1  Older American, Servicemember                        NaN   Postal mail
# 2                            NaN                        NaN           Web
# 3                            NaN                        NaN           Web
# 4                            NaN                        NaN   Postal mail
#
#   Date sent to company     Company response to consumer Timely response?  \
# 0           2016-11-27          Closed with explanation              Yes
# 1           2013-11-13          Closed with explanation              Yes
# 2           2012-07-03      Closed with monetary relief              Yes
# 3           2012-11-19  Closed with non-monetary relief              Yes
# 4           2017-04-21          Closed with explanation              Yes
#
#   Consumer disputed?  Complaint ID
# 0                 No       2202626
# 1                 No        583787
# 2                 No        111425
# 3                 No        193409
# 4                 No       2445864

# %%
# df.shape
# Out:
# (768427, 18)

# %%
df3 = df[df["Consumer disputed?"].isna()].reset_index(drop=True)

# %%
df3.shape
# Out:
# (2510346, 18)

# %%
df3.to_csv("Unlabeled_data.csv",index=False)
