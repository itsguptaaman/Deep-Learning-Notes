# %%
zip_file_url = "https://files.consumerfinance.gov/ccdb/complaints.csv.zip"

# %%
import requests, zipfile, io
r = requests.get(zip_file_url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall("/content/sample_data")

# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/complaints.csv", )
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (9,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Using this location as a root Directory
import os
ROOT = "/content/drive/MyDrive/Colab Notebooks/Deep learning"
os.chdir(ROOT)

# %%
# Checking all the avaliable files
os.listdir()
# Out:
# ['logs',
#  'model_ckp.h5',
#  'model.h5',
#  'ANN_with_callbacks.ipynb',
#  'Handwritten Digit Classification.ipynb',
#  'SAVED_MODELS',
#  'project1',
#  'project3',
#  'APS_in_dl.ipynb',
#  'Mnest.ipynb',
#  'activation function.ipynb',
#  'Batch Normalization.ipynb',
#  'Dataset',
#  'Internship-token.json',
#  'secure-connect-internship.zip',
#  'CNN basics .ipynb']

# %%
df.fillna('Missing', inplace=True)

# %%
import numpy as np
df["ZIP code"]=df["ZIP code"].replace("Missing",np.NAN)

# %%
df.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
# !pip install cassandra-driver
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 45.6 MB/s eta 0:00:00
# ...

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

cloud_config= {
        'secure_connect_bundle': '/content/drive/MyDrive/Colab Notebooks/Deep learning/secure-connect-internship.zip'
}
# <<client_id>> <<client_secret>>
auth_provider = PlainTextAuthProvider("JpYkBNxgdUnRymurXnZcbwzc", "jpju.U1rD1XZOkjt9ydtPzh_jQBWZx22pII-ruOu2OABtnYKT8PDXr2oKRD--ZQcXA03RmNBivWfRbahwfHDKcebKvKDZLNuLuLD_9qCYGr8DTrLXpOvyfgcsyTQ-QMn")
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("select * from system_schema.keyspaces").one()
if row:
    print(row[0])
else:
    print("An error occurred.")
# Out:
# WARNING:cassandra.cluster:Downgrading core protocol version from 66 to 65 for 325b8fe8-0fd0-4604-9ad6-c19ac4a06b57-asia-south1.db.astra.datastax.com:29042:e61f2720-99f2-4c73-8a4b-609584efb68d. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# WARNING:cassandra.cluster:Downgrading core protocol version from 65 to 5 for 325b8fe8-0fd0-4604-9ad6-c19ac4a06b57-asia-south1.db.astra.datastax.com:29042:e61f2720-99f2-4c73-8a4b-609584efb68d. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# ...

# %%
df.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date received                   object
# Product                         object
# Sub-product                     object
# Issue                           object
# Sub-issue                       object
# Consumer complaint narrative    object
# Company public response         object
# Company                         object
# State                           object
# ZIP code                        object
# Tags                            object
# Consumer consent provided?      object
# Submitted via                   object
# Date sent to company            object
# Company response to consumer    object
# Timely response?                object
# Consumer disputed?              object
# Complaint ID                     int64
# dtype: object

# %%
df["Product"] = df["Product"].apply(lambda x:x.replace("'",""))
df["Sub-product"] = df["Sub-product"].apply(lambda x:x.replace("'",""))
df["Issue"] = df["Issue"].apply(lambda x:x.replace("'",""))
df["Sub-issue"] = df["Sub-issue"].apply(lambda x:x.replace("'",""))
df["Consumer complaint narrative"] = df["Consumer complaint narrative"].apply(lambda x:x.replace("'",""))
df["Company public response"] = df["Company public response"].apply(lambda x:x.replace("'",""))
df["Company"] = df["Company"].apply(lambda x:x.replace("'",""))
df["State"] = df["State"].apply(lambda x:x.replace("'",""))
df["Tags"] = df["Tags"].apply(lambda x:x.replace("'",""))
df["Consumer consent provided?"] = df["Consumer consent provided?"].apply(lambda x:x.replace("'",""))
df["Submitted via"] = df["Submitted via"].apply(lambda x:x.replace("'",""))
df["Date sent to company"] = df["Date sent to company"].apply(lambda x:x.replace("'",""))
df["Company response to consumer"] = df["Company response to consumer"].apply(lambda x:x.replace("'",""))
df["Timely response?"] = df["Timely response?"].apply(lambda x:x.replace("'",""))
df["Company"] = df["Company"].apply(lambda x:x.replace("'",""))

# %%
df.head()
# Out:
#   Date received                                            Product  \
# 0    2023-01-24  Credit reporting, credit repair services, or o...
# 1    2023-01-24  Credit reporting, credit repair services, or o...
# 2    2023-01-24  Credit reporting, credit repair services, or o...
# 3    2023-01-18                        Checking or savings account
# 4    2023-01-17  Credit reporting, credit repair services, or o...
#
#         Sub-product                                 Issue  \
# 0  Credit reporting  Incorrect information on your report
# 1  Credit reporting           Improper use of your report
# 2  Credit reporting           Improper use of your report
# 3  Checking account                   Managing an account
# 4  Credit reporting           Improper use of your report
#
#                                            Sub-issue  \
# 0                Information belongs to someone else
# 1  Credit inquiries on your report that you dont ...
# ...

# %%
df.sample(10)
# Out:
#         Date received                                            Product  \
# 2395534    2017-05-21                        Credit card or prepaid card
# 2930509    2014-01-28                            Bank account or service
# 1744304    2017-02-14                                    Debt collection
# 1200483    2015-06-10                                      Consumer Loan
# 3098154    2022-07-19  Credit reporting, credit repair services, or o...
# 3066466    2017-03-07                            Bank account or service
# 1499044    2020-10-19  Credit reporting, credit repair services, or o...
# 1703902    2013-06-20                            Bank account or service
# 2310484    2021-08-17                        Checking or savings account
# 1473522    2020-11-16                        Credit card or prepaid card
#
#                                         Sub-product  \
# 2395534                           Store credit card
# 2930509                            Checking account
# ...

# %%
index=[i for i in range(1, len(df) + 1)]
df.insert(0,"Serial_no",index)

# %%
df.columns
# Out:
# Index(['Serial_no', 'Date received', 'Product', 'Sub-product', 'Issue',
#        'Sub-issue', 'Consumer complaint narrative', 'Company public response',
#        'Company', 'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
df = df.iloc[337522: ,:]

# %%
# Serial_no, Date_received, Product, Sub_product, Issue, Sub_issue, Consumer_complaint_narrative, Company_public_response, Company, State, ZIP_code, Tags, Consumer_consent_provided, Submitted_via, Date_sent_to_company, Company_response_to_consumer, Timely_response, Consumer_disputed, Complaint_ID

# %%
table1=""" create table if not exists dataset.customer_dataset (
SerialNo int PRIMARY KEY,
DateReceived varchar, 
Product varchar, 
SubProduct varchar, 
Issue varchar, 
SubIssue varchar,
ConsumerComplaintNarrative varchar,
CompanyPublicResponse varchar, 
Company varchar,
State varchar, 
ZIPCode float, 
Tags varchar, 
ConsumerConsentProvided varchar,
SubmittedVia varchar, 
DateSentToCompany varchar, 
CompanyResponseToConsumer varchar,
TimelyResponse varchar, 
ConsumerDisputed varchar, 
ComplaintID int)"""

# %%
row = session.execute(table1).one()
if row:
    print(row[0])
else:
    print("Successful.")
# Out:
# Successful.

# %%
for i in range(337522,len(df)):
    data = tuple(df.iloc[i])
    print(i)
    q = f"INSERT INTO dataset.customer_dataset(SerialNo, DateReceived, Product, SubProduct, Issue, SubIssue, ConsumerComplaintNarrative, CompanyPublicResponse, Company, State, ZIPCode, Tags, ConsumerConsentProvided, SubmittedVia, DateSentToCompany, CompanyResponseToConsumer, TimelyResponse, ConsumerDisputed, ComplaintID) VALUES {data}"
    session.execute(q)
# Out:
# Streaming output truncated to the last 5000 lines.
# 366313
# 366314
# 366315
# 366316
# 366317
# 366318
# 366319
# 366320
# 366321
# 366322
# 366323
# 366324
# 366325
# 366326
# 366327
# 366328
# 366329
# 366330
# 366331
# 366332
# 366333
# 366334
# 366335
# 366336
# 366337
# 366338
# 366339
# 366340
# 366341
# 366342
# 366343
# 366344
# 366345
# 366346
# 366347
# 366348
# 366349
# 366350
# 366351
# 366352
# 366353
# 366354
# 366355
# 366356
# 366357
# 366358
# 366359
# 366360
# 366361
# 366362
# 366363
# 366364
# 366365
# 366366
# 366367
# 366368
# 366369
# 366370
# 366371
# 366372
# 366373
# 366374
# 366375
# 366376
# 366377
# 366378
# 366379
# 366380
# 366381
# 366382
# 366383
# 366384
# 366385
# 366386
# 366387
# 366388
# 366389
# 366390
# 366391
# 366392
# 366393
# 366394
# 366395
# 366396
# 366397
# 366398
# 366399
# 366400
# 366401
# 366402
# 366403
# 366404
# 366405
# 366406
# 366407
# 366408
# 366409
# 366410
# 366411
# 366412
# 366413
# 366414
# 366415
# 366416
# 366417
# ...

# %%
371312
